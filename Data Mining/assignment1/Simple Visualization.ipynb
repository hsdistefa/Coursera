# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data taken from https://data.giss.nasa.gov/gistemp/
data = pd.read_csv('data/ExcelFormattedGISTEMPData2CSV.csv')

# Only use global average
temp_df = data[['Year', 'Glob']]

# Convert temperature changes to decimal
temp_df.loc[:, 'Glob'] = temp_df.loc[:, 'Glob'].astype(np.float32) / 100.
temp_df
# Out:
#      Year  Glob
# 0    1880 -0.19
# 1    1881 -0.10
# 2    1882 -0.09
# 3    1883 -0.19
# 4    1884 -0.27
# 5    1885 -0.31
# 6    1886 -0.30
# 7    1887 -0.33
# 8    1888 -0.20
# 9    1889 -0.11
# 10   1890 -0.36
# 11   1891 -0.23
# 12   1892 -0.26
# 13   1893 -0.29
# 14   1894 -0.30
# 15   1895 -0.21
# 16   1896 -0.14
# 17   1897 -0.11
# 18   1898 -0.28
# 19   1899 -0.16
# 20   1900 -0.08
# 21   1901 -0.13
# 22   1902 -0.26
# 23   1903 -0.35
# 24   1904 -0.44
# 25   1905 -0.27
# 26   1906 -0.21
# 27   1907 -0.39
# 28   1908 -0.42
# 29   1909 -0.47
# ..    ...   ...
# 105  1985  0.12
# 106  1986  0.19
# 107  1987  0.34
# 108  1988  0.40
# 109  1989  0.29
# 110  1990  0.44
# 111  1991  0.42
# 112  1992  0.23
# 113  1993  0.24
# 114  1994  0.32
# 115  1995  0.46
# 116  1996  0.35
# 117  1997  0.48
# 118  1998  0.63
# 119  1999  0.42
# 120  2000  0.42
# 121  2001  0.55
# 122  2002  0.63
# 123  2003  0.62
# 124  2004  0.55
# 125  2005  0.69
# 126  2006  0.64
# 127  2007  0.66
# ...

# %%
# Only use global average
ax = temp_df.plot(x='Year', y='Glob', title='Yearly Change in Global Average Temperature Over Time')
ax.set_ylabel('Delta T (deg C)'.format(degree_sign))
